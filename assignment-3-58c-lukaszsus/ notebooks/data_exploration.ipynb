# %%
import os, sys, inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir)
from settings import DATA_PATH

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from utils.plots import params_in_last_n_samples, plot_data

# %%
os.listdir(DATA_PATH)
# Out:
# ['series1.csv', 'series2.csv', 'series3.csv']

# %% [markdown]
# ## Data plots

# %%
window_size = 100
dist_changes_1 = [2700, 5800]
dist_changes_2 = [2800, 5800]

# %%
df_1 = pd.read_csv(os.path.join(DATA_PATH, "series1.csv"))
plot_data(df_1, window_size=window_size, vlines=dist_changes_1)

# %%
df_2 = pd.read_csv(os.path.join(DATA_PATH, "series2.csv"))
plot_data(df_2, window_size=window_size, vlines=dist_changes_2)

# %%
df_3 = pd.read_csv(os.path.join(DATA_PATH, "series3.csv"))
plot_data(df_3, window_size=window_size)
